# %% [markdown]
# # Importer les bibliothèques

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Ouvrir fichier csv : bien identifier le separateur

# %%
file = 'Invoice_20201220.csv'
df = pd.read_csv(file, sep = '|')

# %% [markdown]
# # Apercu du fichier

# %%
df
# Out:
#                 SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD  \
# 0      12345_GEO (0001BB)     1300082549  01/01/2018  31/01/2018      2 447
# 1      12345_GEO (0001BB)     1300082549  01/02/2018  28/02/2018      2 211
# 2      12345_GEO (0001BB)     1300082549  01/03/2018  31/03/2018      2 450
# 3      12345_GEO (0001BB)     1300082549  01/04/2018  30/04/2018      2 431
# 4      12345_GEO (0001BB)     1300082549  01/05/2018  31/05/2018      2 574
# ...                   ...            ...         ...         ...        ...
# 51427  19767_GEO (0632KO)  FV1/055100030  30/08/2019  31/12/2019      3 028
# 51428  19767_GEO (0632KO)      055100058  01/01/2020  31/03/2020      2 163
# 51429  19767_GEO (0632KO)      055100113  01/04/2020  30/06/2020      2 160
# 51430  19767_GEO (0632KO)      055100168  01/07/2020  30/09/2020      2 230
# 51431  19883_GEO (1203KO)     7220278453  27/09/2019  31/12/2019      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 6 columns]

# %% [markdown]
# ## 1) Le nom d'une antenne a un format bien précis : il est toujours composé de 4 chiffres et de deux lettres. On te demande de retirer tout autre caractère de la colonne "SITE_NAME".

# %% [markdown]
# ## Surement methode plus pratique mais on va faire en trois temps :

# %% [markdown]
# ### 1- Garder ce que l'on a apres la premiere parenthese

# %%
df[['SITE','SITE_NAME']] = df['SITE_NAME'].str.split('(',expand=True)

# %%
df
# Out:
#       SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR  \
# 0       0001BB)     1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1       0001BB)     1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2       0001BB)     1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3       0001BB)     1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4       0001BB)     1300082549  01/05/2018  31/05/2018      2 574     333,37
# ...         ...            ...         ...         ...        ...        ...
# 51427   0632KO)  FV1/055100030  30/08/2019  31/12/2019      3 028     397,18
# 51428   0632KO)      055100058  01/01/2020  31/03/2020      2 163     283,57
# 51429   0632KO)      055100113  01/04/2020  30/06/2020      2 160     312,55
# 51430   0632KO)      055100168  01/07/2020  30/09/2020      2 230     294,07
# 51431   1203KO)     7220278453  27/09/2019  31/12/2019      4 745     681,96
#
#              SITE
# 0      12345_GEO
# 1      12345_GEO
# 2      12345_GEO
# 3      12345_GEO
# 4      12345_GEO
# ...           ...
# 51427  19767_GEO
# 51428  19767_GEO
# 51429  19767_GEO
# 51430  19767_GEO
# 51431  19883_GEO
#
# [51432 rows x 7 columns]

# %% [markdown]
# ## Garder ce que l'on a avant la seconde parenthese

# %%
df[['SITE_NAME','SITE2']] = df['SITE_NAME'].str.split(')',expand=True)

# %%
df
# Out:
#       SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR  \
# 0        0001BB     1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB     1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB     1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB     1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB     1300082549  01/05/2018  31/05/2018      2 574     333,37
# ...         ...            ...         ...         ...        ...        ...
# 51427    0632KO  FV1/055100030  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO      055100058  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO      055100113  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO      055100168  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO     7220278453  27/09/2019  31/12/2019      4 745     681,96
#
#              SITE SITE2
# 0      12345_GEO
# 1      12345_GEO
# 2      12345_GEO
# 3      12345_GEO
# 4      12345_GEO
# ...           ...   ...
# 51427  19767_GEO
# 51428  19767_GEO
# 51429  19767_GEO
# 51430  19767_GEO
# 51431  19883_GEO
#
# [51432 rows x 8 columns]

# %% [markdown]
# ## Supprimer les colonnes nouvellement crees

# %%
df = df.drop(columns=['SITE', 'SITE2'])

# %%
df
# Out:
#       SITE_NAME   INVOICE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB     1300082549  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB     1300082549  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB     1300082549  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB     1300082549  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB     1300082549  01/05/2018  31/05/2018      2 574     333,37
# ...         ...            ...         ...         ...        ...        ...
# 51427    0632KO  FV1/055100030  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO      055100058  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO      055100113  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO      055100168  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO     7220278453  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 6 columns]

# %% [markdown]
# ## 2) On te demande de supprimer la colonne "INVOICE_NAME" qui n'apporte rien aux équipes.

# %%
df = df.drop(columns=['INVOICE_NAME'])

# %%
df
# Out:
#       SITE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB  01/05/2018  31/05/2018      2 574     333,37
# ...         ...         ...         ...        ...        ...
# 51427    0632KO  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 5 columns]

# %% [markdown]
# ## 3) Il y a des antennes pour lesquelles on a des factures mensuelles tandis que pour d'autres, on les reçoit moins régulièrement (trimestre, semestre, année). Ajoute une colonne à ton tableau qui calcule le nombre de jours entre le début de la période de facturation et la fin de la période de facturation.

# %%
df
# Out:
#       SITE_NAME       BEGIN         END KWH_PERIOD PERIOD_EUR
# 0        0001BB  01/01/2018  31/01/2018      2 447     316,46
# 1        0001BB  01/02/2018  28/02/2018      2 211     286,82
# 2        0001BB  01/03/2018  31/03/2018      2 450     317,32
# 3        0001BB  01/04/2018  30/04/2018      2 431     315,00
# 4        0001BB  01/05/2018  31/05/2018      2 574     333,37
# ...         ...         ...         ...        ...        ...
# 51427    0632KO  30/08/2019  31/12/2019      3 028     397,18
# 51428    0632KO  01/01/2020  31/03/2020      2 163     283,57
# 51429    0632KO  01/04/2020  30/06/2020      2 160     312,55
# 51430    0632KO  01/07/2020  30/09/2020      2 230     294,07
# 51431    1203KO  27/09/2019  31/12/2019      4 745     681,96
#
# [51432 rows x 5 columns]

# %% [markdown]
# ## Insertion de la colonne des jours

# %%
df.insert(3, "daysPeriod", " ")

# %%
df
# Out:
#       SITE_NAME       BEGIN         END daysPeriod KWH_PERIOD PERIOD_EUR
# 0        0001BB  01/01/2018  31/01/2018                 2 447     316,46
# 1        0001BB  01/02/2018  28/02/2018                 2 211     286,82
# 2        0001BB  01/03/2018  31/03/2018                 2 450     317,32
# 3        0001BB  01/04/2018  30/04/2018                 2 431     315,00
# 4        0001BB  01/05/2018  31/05/2018                 2 574     333,37
# ...         ...         ...         ...        ...        ...        ...
# 51427    0632KO  30/08/2019  31/12/2019                 3 028     397,18
# 51428    0632KO  01/01/2020  31/03/2020                 2 163     283,57
# 51429    0632KO  01/04/2020  30/06/2020                 2 160     312,55
# 51430    0632KO  01/07/2020  30/09/2020                 2 230     294,07
# 51431    1203KO  27/09/2019  31/12/2019                 4 745     681,96
#
# [51432 rows x 6 columns]

# %% [markdown]
# ### Conversion des dates

# %%
df.dtypes
# Out:
# SITE_NAME     object
# BEGIN         object
# END           object
# daysPeriod    object
# KWH_PERIOD    object
# PERIOD_EUR    object
# dtype: object

# %%
df['BEGIN'] = pd.to_datetime(df['BEGIN'], dayfirst=True)
df['END'] = pd.to_datetime(df['END'], dayfirst=True)

# %% [markdown]
# ## Il faut bien ajouter dayfirst = True pour que le format de la date soit respecte

# %% [markdown]
# ## Soustraction et ajout dans la colonne

# %%
df['daysPeriod'] = df['END'] - df['BEGIN']

# %%
df
# Out:
#       SITE_NAME      BEGIN        END daysPeriod KWH_PERIOD PERIOD_EUR
# 0        0001BB 2018-01-01 2018-01-31    30 days      2 447     316,46
# 1        0001BB 2018-02-01 2018-02-28    27 days      2 211     286,82
# 2        0001BB 2018-03-01 2018-03-31    30 days      2 450     317,32
# 3        0001BB 2018-04-01 2018-04-30    29 days      2 431     315,00
# 4        0001BB 2018-05-01 2018-05-31    30 days      2 574     333,37
# ...         ...        ...        ...        ...        ...        ...
# 51427    0632KO 2019-08-30 2019-12-31   123 days      3 028     397,18
# 51428    0632KO 2020-01-01 2020-03-31    90 days      2 163     283,57
# 51429    0632KO 2020-04-01 2020-06-30    90 days      2 160     312,55
# 51430    0632KO 2020-07-01 2020-09-30    91 days      2 230     294,07
# 51431    1203KO 2019-09-27 2019-12-31    95 days      4 745     681,96
#
# [51432 rows x 6 columns]

# %% [markdown]
# ## 4) A partir de cette nouvelle colonne, crée une autre colonne qui nous donne la consommation journalière moyenne de la période.

# %% [markdown]
# ### Insertion de la nouvelle colonne

# %%
df.insert(5, "kwhPerDay", " ")

# %%
df
# Out:
#       SITE_NAME      BEGIN        END daysPeriod KWH_PERIOD kwhPerDay  \
# 0        0001BB 2018-01-01 2018-01-31    30 days      2 447
# 1        0001BB 2018-02-01 2018-02-28    27 days      2 211
# 2        0001BB 2018-03-01 2018-03-31    30 days      2 450
# 3        0001BB 2018-04-01 2018-04-30    29 days      2 431
# 4        0001BB 2018-05-01 2018-05-31    30 days      2 574
# ...         ...        ...        ...        ...        ...       ...
# 51427    0632KO 2019-08-30 2019-12-31   123 days      3 028
# 51428    0632KO 2020-01-01 2020-03-31    90 days      2 163
# 51429    0632KO 2020-04-01 2020-06-30    90 days      2 160
# 51430    0632KO 2020-07-01 2020-09-30    91 days      2 230
# 51431    1203KO 2019-09-27 2019-12-31    95 days      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 7 columns]

# %% [markdown]
# ### Conversion des jours en integer

# %%
df['daysPeriod']
# Out:
# 0        30 days
# 1        27 days
# 2        30 days
# 3        29 days
# 4        30 days
#           ...
# 51427   123 days
# 51428    90 days
# 51429    90 days
# 51430    91 days
# 51431    95 days
# Name: daysPeriod, Length: 51432, dtype: timedelta64[ns]

# %%
# SOURCE : https://stackoverflow.com/questions/25646200/python-convert-timedelta-to-int-in-a-dataframe

# %%
df['daysPeriod'] = pd.to_numeric(df['daysPeriod'].dt.days, downcast='integer')

# %%
df['daysPeriod']
# Out:
# 0         30
# 1         27
# 2         30
# 3         29
# 4         30
#         ...
# 51427    123
# 51428     90
# 51429     90
# 51430     91
# 51431     95
# Name: daysPeriod, Length: 51432, dtype: int16

# %%
df.dtypes
# Out:
# SITE_NAME             object
# BEGIN         datetime64[ns]
# END           datetime64[ns]
# daysPeriod             int16
# KWH_PERIOD            object
# kwhPerDay             object
# PERIOD_EUR            object
# dtype: object

# %%
df
# Out:
#       SITE_NAME      BEGIN        END  daysPeriod KWH_PERIOD kwhPerDay  \
# 0        0001BB 2018-01-01 2018-01-31          30      2 447
# 1        0001BB 2018-02-01 2018-02-28          27      2 211
# 2        0001BB 2018-03-01 2018-03-31          30      2 450
# 3        0001BB 2018-04-01 2018-04-30          29      2 431
# 4        0001BB 2018-05-01 2018-05-31          30      2 574
# ...         ...        ...        ...         ...        ...       ...
# 51427    0632KO 2019-08-30 2019-12-31         123      3 028
# 51428    0632KO 2020-01-01 2020-03-31          90      2 163
# 51429    0632KO 2020-04-01 2020-06-30          90      2 160
# 51430    0632KO 2020-07-01 2020-09-30          91      2 230
# 51431    1203KO 2019-09-27 2019-12-31          95      4 745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 7 columns]

# %% [markdown]
# ### Conversion du KWH_PERIOD en integer

# %% [markdown]
# #### Supprimer l'espace dans le nombre

# %%
# source : https://stackoverflow.com/questions/43332057/pandas-strip-white-space

# %%
df['KWH_PERIOD'] = df['KWH_PERIOD'].str.replace(" ","")

# %%
df
# Out:
#       SITE_NAME      BEGIN        END  daysPeriod KWH_PERIOD kwhPerDay  \
# 0        0001BB 2018-01-01 2018-01-31          30       2447
# 1        0001BB 2018-02-01 2018-02-28          27       2211
# 2        0001BB 2018-03-01 2018-03-31          30       2450
# 3        0001BB 2018-04-01 2018-04-30          29       2431
# 4        0001BB 2018-05-01 2018-05-31          30       2574
# ...         ...        ...        ...         ...        ...       ...
# 51427    0632KO 2019-08-30 2019-12-31         123       3028
# 51428    0632KO 2020-01-01 2020-03-31          90       2163
# 51429    0632KO 2020-04-01 2020-06-30          90       2160
# 51430    0632KO 2020-07-01 2020-09-30          91       2230
# 51431    1203KO 2019-09-27 2019-12-31          95       4745
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 7 columns]

# %%
# source : https://sparkbyexamples.com/pandas/pandas-convert-column-to-int/

# %%
df['KWH_PERIOD'] = df['KWH_PERIOD'].astype('int')

# %%
df.dtypes
# Out:
# SITE_NAME             object
# BEGIN         datetime64[ns]
# END           datetime64[ns]
# daysPeriod             int16
# KWH_PERIOD             int64
# kwhPerDay             object
# PERIOD_EUR            object
# dtype: object

# %% [markdown]
# ### Calcul du khwperday

# %%
df['kwhPerDay'] = (df['KWH_PERIOD']/df['daysPeriod']).round(decimals = 2)

# %%
df
# Out:
#       SITE_NAME      BEGIN        END  daysPeriod  KWH_PERIOD  kwhPerDay  \
# 0        0001BB 2018-01-01 2018-01-31          30        2447      81.57
# 1        0001BB 2018-02-01 2018-02-28          27        2211      81.89
# 2        0001BB 2018-03-01 2018-03-31          30        2450      81.67
# 3        0001BB 2018-04-01 2018-04-30          29        2431      83.83
# 4        0001BB 2018-05-01 2018-05-31          30        2574      85.80
# ...         ...        ...        ...         ...         ...        ...
# 51427    0632KO 2019-08-30 2019-12-31         123        3028      24.62
# 51428    0632KO 2020-01-01 2020-03-31          90        2163      24.03
# 51429    0632KO 2020-04-01 2020-06-30          90        2160      24.00
# 51430    0632KO 2020-07-01 2020-09-30          91        2230      24.51
# 51431    1203KO 2019-09-27 2019-12-31          95        4745      49.95
#
#       PERIOD_EUR
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 7 columns]

# %% [markdown]
# ## 5) Merci d'ajouter également une colonne qui donne, pour chaque antenne, le nombre de factures dont on dispose au total. Pas grave si l'information se répète à chaque ligne pour une même antenne.

# %%
nbInvoice = df.pivot_table(columns=['SITE_NAME'], aggfunc='size')
nbInvoice.head
# Out:
# <bound method NDFrame.head of SITE_NAME
#           11
# 0001BB    35
# 0001BR    35
# 0001KO    35
# 0002BB    35
#           ..
# 9513BB     2
# 9515BB     2
# 9516BB     2
# 9517BB     2
# 9518BB     2
# Length: 2403, dtype: int64>

# %%
df.insert(7, "nbInvoice", " ")

# %%
df
# Out:
#       SITE_NAME      BEGIN        END  daysPeriod  KWH_PERIOD  kwhPerDay  \
# 0        0001BB 2018-01-01 2018-01-31          30        2447      81.57
# 1        0001BB 2018-02-01 2018-02-28          27        2211      81.89
# 2        0001BB 2018-03-01 2018-03-31          30        2450      81.67
# 3        0001BB 2018-04-01 2018-04-30          29        2431      83.83
# 4        0001BB 2018-05-01 2018-05-31          30        2574      85.80
# ...         ...        ...        ...         ...         ...        ...
# 51427    0632KO 2019-08-30 2019-12-31         123        3028      24.62
# 51428    0632KO 2020-01-01 2020-03-31          90        2163      24.03
# 51429    0632KO 2020-04-01 2020-06-30          90        2160      24.00
# 51430    0632KO 2020-07-01 2020-09-30          91        2230      24.51
# 51431    1203KO 2019-09-27 2019-12-31          95        4745      49.95
#
#       PERIOD_EUR nbInvoice
# 0         316,46
# 1         286,82
# 2         317,32
# 3         315,00
# 4         333,37
# ...          ...       ...
# 51427     397,18
# 51428     283,57
# 51429     312,55
# 51430     294,07
# 51431     681,96
#
# [51432 rows x 8 columns]

# %% [markdown]
# ## 6) Et information bonus si tu y arrives : les équipes aimeraient beaucoup avoir une liste de toutes les antennes avec, pour chaque antenne, le coefficient de variation de la consommation. Cela permettra d'avoir une idée, pour chaque antenne, de la dispersion de sa consommation d'énergie.

# %% [markdown]
# ## 7) Enfin, tu dois exporter ces deux fichiers obtenus pour pouvoir l'envoyer aux équipes de l'opérateur et leur demander si c'est bien cela qu'ils attendaient de toi.

# %%
df.to_csv('newEnergie.csv' , index=False)
